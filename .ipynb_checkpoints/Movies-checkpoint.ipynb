# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from scipy.stats import norm

# %%
data=pd.read_csv("movies.csv")
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                    1000  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 28 columns):
# color                        397 non-null object
# director_name                397 non-null object
# num_critic_for_reviews       397 non-null float64
# duration                     396 non-null float64
# director_facebook_likes      397 non-null float64
# actor_3_facebook_likes       397 non-null float64
# actor_2_name                 398 non-null object
# actor_1_facebook_likes       399 non-null int64
# gross                        388 non-null float64
# genres                       399 non-null object
# actor_1_name                 399 non-null object
# movie_title                  399 non-null object
# num_voted_users              399 non-null int64
# cast_total_facebook_likes    399 non-null int64
# actor_3_name                 397 non-null object
# facenumber_in_poster         397 non-null float64
# plot_keywords                394 non-null object
# ...

# %%
data.isnull().sum()
# Out:
# color                         2
# director_name                 2
# num_critic_for_reviews        2
# duration                      3
# director_facebook_likes       2
# actor_3_facebook_likes        2
# actor_2_name                  1
# actor_1_facebook_likes        0
# gross                        11
# genres                        0
# actor_1_name                  0
# movie_title                   0
# num_voted_users               0
# cast_total_facebook_likes     0
# actor_3_name                  2
# facenumber_in_poster          2
# plot_keywords                 5
# movie_imdb_link               0
# num_user_for_reviews          2
# language                      2
# country                       2
# content_rating                7
# budget                       10
# title_year                    4
# actor_2_facebook_likes        1
# imdb_score                    0
# aspect_ratio                  5
# movie_facebook_likes          0
# dtype: int64

# %%
sns.countplot(x="country", hue="language", data=data)
sns.set(rc={'figure.figsize':(200,5)})

# %%
sns.relplot(x="country", y="budget", data=data)
sns.set(rc={'figure.figsize':(200,5)})

# %%
sns.scatterplot(x="country", y="language",hue="title_year", data=data)
sns.set(rc={'figure.figsize':(10,5)})

# %%
sns.lineplot(x="content_rating", y="budget", hue="language", data=data)

# %%
data.head(1)
# Out:
#    color  director_name  num_critic_for_reviews  duration  \
# 0  Color  James Cameron                   723.0     178.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                    1000  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
#
#   movie_facebook_likes
# 0                33000
#
# [1 rows x 28 columns]

# %%
sns.catplot(x="director_name", y="director_facebook_likes", hue="language", data=data)
sns.set(rc={'figure.figsize':(200,15)})

# %%
sns.stripplot(x="imdb_score", y="budget", data=data)
sns.set(rc={'figure.figsize':(20,5)})

# %%
sns.swarmplot(x="imdb_score", y="budget", data=data)
sns.set(rc={'figure.figsize':(20,5)})
# Out:
# C:\Users\Siddarth\Anaconda3\lib\site-packages\seaborn\categorical.py:1324: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\Siddarth\Anaconda3\lib\site-packages\seaborn\categorical.py:1328: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.boxplot(x="imdb_score", y="budget", data=data)
sns.set(rc={'figure.figsize':(20,5)})

# %%
sns.violinplot(x="imdb_score", y="budget", data=data)
sns.set(rc={'figure.figsize':(20,5)})

# %%
sns.boxenplot(x="imdb_score", y="budget", data=data)
sns.set(rc={'figure.figsize':(20,5)})

# %%
sns.barplot(x="imdb_score", y="budget", data=data)
sns.set(rc={'figure.figsize':(20,5)})

# %%
sns.countplot(x="imdb_score", hue="country", data=data)
edgecolor=sns.color_palette("dark", 3)
sns.set(rc={'figure.figsize':(20,5)})
edgecolor
# Out:
# [(0.0, 0.10980392156862745, 0.4980392156862745),
#  (0.6941176470588235, 0.25098039215686274, 0.050980392156862744),
#  (0.07058823529411765, 0.44313725490196076, 0.10980392156862745)]

# %%
sns.countplot(x="imdb_score", hue="country",palette="Set3",facecolor=(0,0,0,0),linewidth=5, data=data)
sns.set(rc={'figure.figsize':(20,5)}, style="darkgrid")

# %%
data.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                    1000  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                   40000  309404152.0         Action|Adventure|Fantasy  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# ...

# %%
sns.jointplot(x="imdb_score", y="budget", data=data)
sns.set(rc={'figure.figsize':(20,5)}, style="ticks", color_codes=True)

# %%
sns.jointplot(x="imdb_score", y="budget",kind="reg", data=data)
sns.set(rc={'figure.figsize':(20,5)})

# %%
sns.jointplot("imdb_score", "budget",kind="reg", data=data)
sns.set(rc={'figure.figsize':(20,5)})

# %%
sns.pairplot(data=data)
sns.set(rc={'figure.figsize':(20,5)})
# Out:
# C:\Users\Siddarth\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Siddarth\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
x = np.random.randn(100)
sns.distplot(x, rug=True, hist=False, fit=norm, kde=False)
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.distplot(x)

# %%
x = np.random.randn(100)
sns.set(rc={'figure.figsize':(20,5)})
ax=sns.distplot(x, rug=True, hist=False, fit=norm, kde=False)

# %%
data.drop(["actor_1_name"], axis=1, inplace=True)

# %%
data.head(2)
# Out:
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes  actor_1_facebook_likes        gross  \
# 0                   855.0                    1000  760505847.0
# 1                  1000.0                   40000  309404152.0
#
#    num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# 0           886204                       4834                   0.0
# 1           471220                      48350                   0.0
#
#    num_user_for_reviews       budget  title_year  actor_2_facebook_likes  \
# 0                3054.0  237000000.0      2009.0                   936.0
# 1                1238.0  300000000.0      2007.0                  5000.0
#
#    imdb_score  aspect_ratio  movie_facebook_likes
# 0         7.9          1.78                 33000
# 1         7.1          2.35                     0

# %%
sns.kdeplot(data=data)
sns.set(rc={'figure.figsize':(20,5)})
# Out:
# C:\Users\Siddarth\Anaconda3\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)
# C:\Users\Siddarth\Anaconda3\lib\site-packages\matplotlib\contour.py:1520: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# C:\Users\Siddarth\Anaconda3\lib\site-packages\matplotlib\contour.py:1521: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# C:\Users\Siddarth\Anaconda3\lib\site-packages\matplotlib\contour.py:1169: RuntimeWarning: invalid value encountered in less
#   under = np.nonzero(lev < self.zmin)[0]
# C:\Users\Siddarth\Anaconda3\lib\site-packages\matplotlib\contour.py:1171: RuntimeWarning: invalid value encountered in greater
#   over = np.nonzero(lev > self.zmax)[0]
# ...

# %%
x=np.random.randn(100)
sns.set(rc={'figure.figsize':(15,5)})
ax=sns.rugplot(x)

# %%
sns.lmplot("num_user_for_reviews","budget", data=data, hue="title_year", palette="coolwarm",size=6,aspect=1,fit_reg=False)
sns.set(rc={'figure.figsize':(20,9)})
sns.set_style('whitegrid')

# %%
sns.regplot(x="num_user_for_reviews", y="budget", data=data)

# %%
sns.residplot(x="num_user_for_reviews", y="budget", data=data)

# %%
sns.heatmap(data, yticklabels=False, cmap="viridis", cbar=False)

# %%
sns.PairGrid(data=data)

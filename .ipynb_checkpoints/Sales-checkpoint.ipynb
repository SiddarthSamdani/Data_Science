# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

sales = pd.read_csv("100 Sales Records.csv")
sales.head(5)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
sales.isnull()
# Out:
#     Region  Country  Item Type  Sales Channel  Order Priority  Order Date  \
# 0    False    False      False          False           False       False
# 1    False    False      False          False           False       False
# 2    False    False      False          False           False       False
# 3    False    False      False          False           False       False
# 4    False    False      False          False           False       False
# 5    False    False      False          False           False       False
# 6    False    False      False          False           False       False
# 7    False    False      False          False           False       False
# 8    False    False      False          False           False       False
# 9    False    False      False          False           False       False
# 10   False    False      False          False           False       False
# 11   False    False      False          False           False       False
# ...

# %%
sales.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
sns.heatmap(sales.isnull(), yticklabels=False, cmap="viridis")

# %%
sales.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
sns.countplot(x="Item Type", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(60,7)})

# %%
sales.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
sns.lineplot(x="Unit Cost", y="Unit Price", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.relplot(x="Unit Cost", y="Unit Price", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.scatterplot(x="Unit Cost", y="Unit Price", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.catplot(x="Unit Cost", y="Unit Price", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.stripplot(x="Unit Cost", y="Unit Price", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.swarmplot(x="Unit Cost", y="Unit Price", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.boxplot(x="Unit Cost", y="Unit Price", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.violinplot(x="Unit Cost", y="Unit Price", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.boxenplot(x="Unit Cost", y="Unit Price", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.barplot(x="Unit Cost", y="Unit Price", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.jointplot(x="Unit Cost", y="Unit Price", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.pairplot(hue="Sales Channel", hue_order="Country", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.countplot(x="Country", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(2000,7)})
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x00000252EFB84BF8> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~\Anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
# ...

# %%
sns.pointplot(x="Unit Cost", y="Unit Price", hue="Sales Channel", data=sales)
sns.set(rc={'figure.figsize':(2000,7)})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-fb9d5d7d27c7> in <module>
# ----> 1 sns.pointplot(x="Unit Cost", y="Unit Price", hue="Sales Channel", data=sales)
#       2 sns.set(rc={'figure.figsize':(2000,7)})
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, ax, **kwargs)
#    3338         ax = plt.gca()
#    3339
# -> 3340     plotter.plot(ax)
#    3341     return ax
#    3342
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax)
#    1809     def plot(self, ax):
#    1810         """Make the plot."""
# -> 1811         self.draw_points(ax)
#    1812         self.annotate_axes(ax)
#    1813         if self.orient == "h":
#
# ...

# %%
sns.lmplot(x="Unit Cost", y="Unit Price", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.regplot(x="Unit Cost", y="Unit Price", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

# %%
sns.residplot(x="Unit Cost", y="Unit Price", data=sales)
sns.set(rc={'figure.figsize':(20,7)})

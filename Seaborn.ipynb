# %%
import pandas as pd
import numpy as np
import seaborn as sns

data = pd.read_csv("movies.csv")
data.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                    1000  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                   40000  309404152.0         Action|Adventure|Fantasy  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# ...

# %%
sns.countplot(x="country", hue="language", data=data)
sns.set(rc={'figure.figsize':(80,9)})

# %%
sns.relplot(x="budget", y="gross", data=data)

# %%
sns.scatterplot(x="budget", y="gross",hue="country", data=data)
sns.set(rc={'figure.figsize':(20,9)})

# %%
sns.lineplot(x="budget", y="gross",hue="country", data=data)
sns.set(rc={'figure.figsize':(20,9)})

# %%
sns.catplot(x="budget", y="gross",hue="country", data=data)
sns.set(rc={'figure.figsize':(20,9)})

# %%
sns.stripplot(x="budget", y="gross",hue="country", data=data)
sns.set(rc={'figure.figsize':(20,9)})

# %%
sns.swarmplot(x="budget", y="gross",hue="country", data=data)
sns.set(rc={'figure.figsize':(20,9)})
# Out:
# C:\Users\Siddarth\Anaconda3\lib\site-packages\seaborn\categorical.py:1324: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\Siddarth\Anaconda3\lib\site-packages\seaborn\categorical.py:1328: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.boxplot(x="budget", y="gross",hue="country", data=data)
sns.set(rc={'figure.figsize':(20,9)})

# %%
sns.violinplot(x="budget", y="gross",hue="country", data=data)
sns.set(rc={'figure.figsize':(20,9)})

# %%
sns.boxenplot(x="budget", y="gross",hue="country", data=data)
sns.set(rc={'figure.figsize':(20,9)})

# %%
sns.pointplot(x="budget", y="gross",hue="language", data=data)
sns.set(rc={'figure.figsize':(20,9)})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-ce732d6d6497> in <module>
# ----> 1 sns.pointplot(x="budget", y="gross",hue="language", data=data)
#       2 sns.set(rc={'figure.figsize':(20,9)})
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, ax, **kwargs)
#    3338         ax = plt.gca()
#    3339
# -> 3340     plotter.plot(ax)
#    3341     return ax
#    3342
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax)
#    1809     def plot(self, ax):
#    1810         """Make the plot."""
# -> 1811         self.draw_points(ax)
#    1812         self.annotate_axes(ax)
#    1813         if self.orient == "h":
#
# ...

# %%
sns.barplot(x="budget", y="gross",hue="country", data=data)
sns.set(rc={'figure.figsize':(20,9)})

# %%
sns.countplot(x="budget",hue="country", data=data)
sns.set(rc={'figure.figsize':(20,9)})
